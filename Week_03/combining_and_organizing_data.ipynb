# %% [markdown]
# # Combining & organizing data

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import pandas as pd
import numpy as np
import fnmatch

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# Show current working directory
print(os.getcwd())
# Out:
# /workspaces/data_analytics/Week_03

# %% [markdown]
# ## Importing the prepared rental apartments data

# %%
# Read data to pandas data frame
df_orig = pd.read_csv('apartments_data_prepared.csv', 
                      sep=',', 
                      encoding='utf-8')

# Copy of data with selected colums
columns = [ 'web-scraper-order', 
            'address_raw',
            'rooms', 
            'area', 
            'luxurious',
            'price',
            'price_per_m2']
df = df_orig[columns]

# Get number of rows and columns
print(df.shape)

# Show first records
df.head(5)
# Out:
# (865, 7)
#   web-scraper-order                          address_raw  rooms  area  \
# 0      1693998201-1    Neuhusstrasse 6, 8630 Rüti ZH, ZH    3.0  49.0
# 1      1693998201-2   Zürcherstrasse 1, 8173 Neerach, ZH    3.5  65.0
# 2      1693998201-4  Cramerstrasse 8-12, 8004 Zürich, ZH    2.0  54.0
# 3      1693998201-5    Rotachstrasse 33, 8003 Zürich, ZH    2.0  49.0
# 4     1693998201-16      Wolframplatz 1, 8045 Zürich, ZH    2.0  32.0
#
#    luxurious   price  price_per_m2
# 0          0  1441.0         29.41
# 1          0  1850.0         28.46
# 2          0  4853.0         89.87
# 3          0  4335.0         88.47
# 4          0  3515.0        109.84

# %% [markdown]
# ## Combining data from different sources

# %% [markdown]
# ### Reading rental apartment data with geocoded addresses

# %%
# Meaning of variables
# lat: geographical latitude
# lon: geographical longitude
# bfs_number: official municipality id
# bfs_name: official municipality name

# Geocoded data (i.e. data with latitude and longitude)
df_geo = pd.read_csv('apartments_data_geocoded.csv', 
                     sep=',', 
                     encoding='utf-8')

# Rename columns
df_geo = df_geo.rename(columns={'web-scrape':'web-scraper-order',
                                'address_ra':'address_raw',
                                'BFS_NUMMER':'bfs_number', 
                                'NAME':'bfs_name'})

# Show data
df_geo[['web-scraper-order',
        'address_raw',
        'lat', 
        'lon', 
        'bfs_number', 
        'bfs_name']].head()
# Out:
#   web-scraper-order                           address_raw        lat  \
# 0      1693998201-1     Neuhusstrasse 6, 8630 Rüti ZH, ZH  47.252171
# 1      1693998201-2    Zürcherstrasse 1, 8173 Neerach, ZH  47.513332
# 2      1693998201-5     Rotachstrasse 33, 8003 Zürich, ZH  47.370792
# 3     1693998201-16       Wolframplatz 1, 8045 Zürich, ZH  47.362282
# 4     1693998205-25  Badenerstrasse 67, 8953 Dietikon, ZH  47.407925
#
#         lon  bfs_number   bfs_name
# 0  8.845797         118  Rüti (ZH)
# 1  8.474851          88    Neerach
# 2  8.514748         261     Zürich
# 3  8.522193         261     Zürich
# 4  8.392561         243   Dietikon

# %% [markdown]
# ### Join geo-information to rental apartment data using .merge()

# %%
df2 = df.merge(df_geo[['web-scraper-order', 
                       'lat', 
                       'lon', 
                       'bfs_number', 
                       'bfs_name']], 
               on="web-scraper-order")
df2.head()
# Out:
#   web-scraper-order                           address_raw  rooms   area  \
# 0      1693998201-1     Neuhusstrasse 6, 8630 Rüti ZH, ZH    3.0   49.0
# 1      1693998201-2    Zürcherstrasse 1, 8173 Neerach, ZH    3.5   65.0
# 2      1693998201-5     Rotachstrasse 33, 8003 Zürich, ZH    2.0   49.0
# 3     1693998201-16       Wolframplatz 1, 8045 Zürich, ZH    2.0   32.0
# 4     1693998205-25  Badenerstrasse 67, 8953 Dietikon, ZH    3.5  105.0
#
#    luxurious   price  price_per_m2        lat       lon  bfs_number   bfs_name
# 0          0  1441.0         29.41  47.252171  8.845797         118  Rüti (ZH)
# 1          0  1850.0         28.46  47.513332  8.474851          88    Neerach
# 2          0  4335.0         88.47  47.370792  8.514748         261     Zürich
# 3          0  3515.0        109.84  47.362282  8.522193         261     Zürich
# 4          0  3200.0         30.48  47.407925  8.392561         243   Dietikon

# %% [markdown]
# ### Reading municipality-level data

# %%
# Meaning of variables:
# bfs_number: official municipality id
# bfs_name: official municipality name
# pop: number of residents (=population)
# pop_dens: population density (pop per km2)
# frg_pct: percentage foreigners
# emp: numer of employee
# mean_taxable_income: mean taxable income

df_municip = pd.read_excel('municipality_data.xlsx', 
                           sheet_name='data_for_import')
df_municip.head(5)
# Out:
#    bfs_number            bfs_name    pop     pop_dens    frg_pct     emp  \
# 0           1     Aeugst am Albis   1981   250.442478  14.184755   442.0
# 1           2  Affoltern am Albis  12303  1161.756374  28.700317  6920.0
# 2           3          Bonstetten   5572   749.932705  16.564968  1014.0
# 3           4     Hausen am Albis   3751   275.808824  16.022394  1021.0
# 4           5            Hedingen   3778   578.560490  16.410799  1478.0
#
#    mean_taxable_income
# 0        105013.570634
# 1         71059.805603
# 2         88927.698145
# 3         86300.455137
# 4         90811.205330

# %% [markdown]
# ### Join municipality data to rental apartment data using .merge()

# %%
# Merge needs a key which must be identical in both data sets (here the key is 'bfs_number')
df3 = df2.merge(df_municip[['bfs_number', 
                            'pop', 
                            'pop_dens', 
                            'frg_pct', 
                            'emp', 'mean_taxable_income']], 
                on="bfs_number")

int
df3.head(5)
# Out:
#   web-scraper-order                           address_raw  rooms   area  \
# 0      1693998201-1     Neuhusstrasse 6, 8630 Rüti ZH, ZH    3.0   49.0
# 1      1693998201-2    Zürcherstrasse 1, 8173 Neerach, ZH    3.5   65.0
# 2      1693998201-5     Rotachstrasse 33, 8003 Zürich, ZH    2.0   49.0
# 3     1693998201-16       Wolframplatz 1, 8045 Zürich, ZH    2.0   32.0
# 4     1693998205-25  Badenerstrasse 67, 8953 Dietikon, ZH    3.5  105.0
#
#    luxurious   price  price_per_m2        lat       lon  bfs_number  \
# 0          0  1441.0         29.41  47.252171  8.845797         118
# 1          0  1850.0         28.46  47.513332  8.474851          88
# 2          0  4335.0         88.47  47.370792  8.514748         261
# 3          0  3515.0        109.84  47.362282  8.522193         261
# 4          0  3200.0         30.48  47.407925  8.392561         243
#
#     bfs_name     pop     pop_dens    frg_pct       emp  mean_taxable_income
# 0  Rüti (ZH)   12286  1221.272366  24.841283    5053.0         65362.042683
# 1    Neerach    3175   525.662252  13.322835     641.0        111422.358722
# 2     Zürich  420217  4778.994655  32.458468  491193.0         82932.737704
# 3     Zürich  420217  4778.994655  32.458468  491193.0         82932.737704
# 4   Dietikon   27746  2970.663812  46.226483   18911.0         64662.737784

# %% [markdown]
# ### Export data to file

# %%
# Remove missing values which may have ocured from the merging process
df3 = df3.dropna()

# Check for missing values per column
print(df3.isna().sum())

# Count number of rows and columns
print(df3.shape)

# Export apartment data to file
df3.to_csv('apartments_data_enriched.csv',
            sep=',',
            encoding='utf-8')
# Out:
# web-scraper-order      0
# address_raw            0
# rooms                  0
# area                   0
# luxurious              0
# price                  0
# price_per_m2           0
# lat                    0
# lon                    0
# bfs_number             0
# bfs_name               0
# pop                    0
# pop_dens               0
# frg_pct                0
# emp                    0
# mean_taxable_income    0
# dtype: int64
# (786, 16)

# %% [markdown]
# ### Sorting data

# %%
# Sorting data by 'price' and 'area' with highest price above (ascending=False)
df3.sort_values(by=['price', 'area'], 
                ascending=False).head()
# Out:
#     web-scraper-order                             address_raw  rooms   area  \
# 261    1693998265-365    Gustav-Gull-Platz 4, 8004 Zürich, ZH    4.5  140.0
# 262    1693998265-366               Engweg 8, 8006 Zürich, ZH    4.5  140.0
# 145    1693998236-207        Etzelstrasse 35, 8038 Zürich, ZH    3.5  100.0
# 136    1693998236-197             Utoquai 37, 8008 Zürich, ZH    3.5  169.0
# 346    1693998285-475  Universitätstrasse 41, 8006 Zürich, ZH    4.5  140.0
#
#      luxurious   price  price_per_m2        lat       lon  bfs_number  \
# 261          0  9950.0         71.07  47.379471  8.531120         261
# 262          0  9170.0         65.50  47.385265  8.537632         261
# 145          1  9150.0         91.50  47.346546  8.530695         261
# 136          0  9000.0         53.25  47.363682  8.546781         261
# 346          0  8990.0         64.21  47.380440  8.547943         261
#
#     bfs_name     pop     pop_dens    frg_pct       emp  mean_taxable_income
# 261   Zürich  420217  4778.994655  32.458468  491193.0         82932.737704
# 262   Zürich  420217  4778.994655  32.458468  491193.0         82932.737704
# 145   Zürich  420217  4778.994655  32.458468  491193.0         82932.737704
# 136   Zürich  420217  4778.994655  32.458468  491193.0         82932.737704
# 346   Zürich  420217  4778.994655  32.458468  491193.0         82932.737704

# %% [markdown]
# ### Aggregation of data

# %%
# Aggregation using .groupby()
df3[['rooms', 'price']].groupby(['rooms']).mean()
# Out:
#              price
# rooms
# 1.0    1306.346154
# 1.5    2110.166667
# 2.0    2155.846154
# 2.5    2423.468085
# 3.0    1964.022727
# 3.5    2699.044335
# 4.0    2852.357143
# 4.5    3067.847561
# 5.0    2881.666667
# 5.5    3523.094340
# 6.0    3833.333333
# 6.5    3787.000000
# 7.0    6350.000000
# 7.5    4765.000000
# 8.5    8500.000000

# %% [markdown]
# ## Reshaping data

# %% [markdown]
# ### Reshaping data using .stack() and .unstack()

# %%
df_sub = df3[['bfs_name', 'rooms', 'price', 'area']][:5]
print('Original shape')
print(df_sub, '\n')

df_sub_stacked = df_sub.stack()
print('Stacked')
print(df_sub_stacked, '\n')

# Using unstack
print('Unstacked (= back to original shape)')
print(df_sub_stacked.unstack())
# Out:
# Original shape
#     bfs_name  rooms   price   area
# 0  Rüti (ZH)    3.0  1441.0   49.0
# 1    Neerach    3.5  1850.0   65.0
# 2     Zürich    2.0  4335.0   49.0
# 3     Zürich    2.0  3515.0   32.0
# 4   Dietikon    3.5  3200.0  105.0
#
# Stacked
# 0  bfs_name    Rüti (ZH)
#    rooms             3.0
#    price          1441.0
#    area             49.0
# 1  bfs_name      Neerach
#    rooms             3.5
#    price          1850.0
#    area             65.0
# 2  bfs_name       Zürich
#    rooms             2.0
#    price          4335.0
#    area             49.0
# 3  bfs_name       Zürich
#    rooms             2.0
#    price          3515.0
#    area             32.0
# 4  bfs_name     Dietikon
#    rooms             3.5
#    price          3200.0
#    area            105.0
# dtype: object
#
# Unstacked (= back to original shape)
#     bfs_name rooms   price   area
# 0  Rüti (ZH)   3.0  1441.0   49.0
# 1    Neerach   3.5  1850.0   65.0
# 2     Zürich   2.0  4335.0   49.0
# 3     Zürich   2.0  3515.0   32.0
# 4   Dietikon   3.5  3200.0  105.0

# %% [markdown]
# ### Reshaping data using .melt()

# %%
df_sub = df3[['rooms', 'price', 'area']][:5]
print('Original shape')
print(df_sub, '\n')

print('Reshaped using .melt()')
print(pd.melt(df, id_vars=['rooms'], value_vars=['price', 'area']))
# Out:
# Original shape
#    rooms   price   area
# 0    3.0  1441.0   49.0
# 1    3.5  1850.0   65.0
# 2    2.0  4335.0   49.0
# 3    2.0  3515.0   32.0
# 4    3.5  3200.0  105.0
#
# Reshaped using .melt()
#       rooms variable   value
# 0       3.0    price  1441.0
# 1       3.5    price  1850.0
# 2       2.0    price  4853.0
# 3       2.0    price  4335.0
# 4       2.0    price  3515.0
# ...     ...      ...     ...
# 1725    3.5     area    82.0
# 1726    4.0     area    73.0
# 1727    4.5     area   110.0
# 1728    3.0     area    68.0
# 1729    4.5     area   114.0
#
# [1730 rows x 3 columns]

# %% [markdown]
# ### Pivoting data using .pivot_table()

# %% [markdown]
# ## c)

# %%
# Using pivot_table to reshape the data and calculate means 
pd.pivot_table(df3[['rooms', 'price', 'area', 'price_per_m2']],
               index=['rooms'],
               values=['price', 'area'],
               aggfunc=(np.mean)).assign(price_per_m2=lambda x: x['price'] / x['area'])
# Out:
#              area        price  price_per_m2
# rooms
# 1.0     32.057692  1306.346154     40.749850
# 1.5     35.333333  2110.166667     59.721698
# 2.0     54.589744  2155.846154     39.491780
# 2.5     67.028369  2423.468085     36.155857
# 3.0     68.159091  1964.022727     28.815272
# 3.5     89.945813  2699.044335     30.007448
# 4.0     98.464286  2852.357143     28.968444
# 4.5    115.060976  3067.847561     26.662798
# 5.0    108.000000  2881.666667     26.682099
# 5.5    153.811321  3523.094340     22.905299
# 6.0    667.666667  3833.333333      5.741388
# 6.5    256.357143  3787.000000     14.772360
# 7.0    175.000000  6350.000000     36.285714
# 7.5    205.000000  4765.000000     23.243902
# 8.5    210.000000  8500.000000     40.476190

# %% [markdown]
# ## d) & e)
# My observation is that larger apartment areas have a lower price per m². My assumption is that apartments outside central locations are much larger and therefore much cheaper, which affects the price.

# %% [markdown]
# # f)

# %%
# Erstelle eine Pivot-Tabelle mit der Aggregationsfunktion 'count'
pivot_table_count = pd.pivot_table(df3[['rooms', 'price', 'area', 'price_per_m2']],
                                   index=['rooms'],
                                   values=['price'],
                                   aggfunc='count')

# Zeige die Pivot-Tabelle an
print(pivot_table_count)

# Beschreibung der Pivot-Tabelle
print("\nDie Pivot-Tabelle zeigt die Verteilung der Anzahl der Wohnungen basierend auf der Anzahl der Zimmer. Jeder Eintrag repräsentiert die Anzahl der Wohnungen mit der entsprechenden Anzahl an Zimmern.")
# Out:
#        price
# rooms
# 1.0       52
# 1.5       36
# 2.0       39
# 2.5      141
# 3.0       44
# 3.5      203
# 4.0       28
# 4.5      164
# 5.0        3
# 5.5       53
# 6.0        3
# 6.5       14
# 7.0        2
# 7.5        3
# 8.5        1
#
# Die Pivot-Tabelle zeigt die Verteilung der Anzahl der Wohnungen basierend auf der Anzahl der Zimmer. Jeder Eintrag repräsentiert die Anzahl der Wohnungen mit der entsprechenden Anzahl an Zimmern.

# %% [markdown]
# # g)

# %%
# Erstelle eine Pivot-Tabelle mit Durchschnittswerten pro Gemeinde
pivot_table_municipality = pd.pivot_table(df3, 
                                          index='bfs_name', 
                                          values=['rooms', 'area', 'price', 'price_per_m2'], 
                                          aggfunc=np.mean)

# Sortiere die Pivot-Tabelle nach Preis und Fläche, wobei die teuersten Gemeinden oben stehen
pivot_table_municipality = pivot_table_municipality.sort_values(by=['price', 'area'], ascending=False)

# Zeige die Pivot-Tabelle an
print(pivot_table_municipality)
# Out:
#                       area        price  price_per_m2  rooms
# bfs_name
# Rüschlikon      144.000000  6660.000000     46.250000    4.5
# Küsnacht (ZH)   136.333333  4891.666667     35.476667    4.5
# Nürensdorf      506.500000  4500.000000     17.605000    6.0
# Maur            138.500000  4250.000000     30.445000    4.5
# Obfelden        127.500000  4095.000000     31.910000    5.5
# ...                    ...          ...           ...    ...
# Weiningen (ZH)   73.333333  1606.666667     20.716667    3.0
# Dättlikon        90.000000  1480.000000     16.440000    4.0
# Weiach           46.000000  1420.000000     30.870000    1.5
# Herrliberg       18.000000  1150.000000     63.890000    1.0
# Uetikon am See  300.000000    11.000000      0.040000    6.5
#
# [104 rows x 4 columns]

# %%
from wordcloud import WordCloud

import matplotlib.pyplot as plt

# Erstelle eine Pivot-Tabelle mit der Anzahl der Wohnungen pro Gemeinde
pivot_table_count = pd.pivot_table(df3[['bfs_name', 'web-scraper-order']],
                                   index='bfs_name',
                                   aggfunc='count')

# Erstelle eine Wordcloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(pivot_table_count['web-scraper-order'])

# Zeige die Wordcloud an
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each submitted notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# POSIX
# Linux | 6.5.0-1025-azure
# Datetime: 2024-10-04 12:12:15
# Python Version: 3.11.10
# -----------------------------------
