# %% [markdown]
# # Getting all available Swiss supermarkets using the overpass Web API

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import requests
import json
import folium
from pandas import json_normalize

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# Show current working directory
print(os.getcwd())
# Out:
# /workspaces/data_analytics/Week_01

# %% [markdown]
# ## Overpass turbo query to get all available supermarkets in Switzerland

# %%
# Overpass API URL
url = 'http://overpass-api.de/api/interpreter'

# Overpass turbo query
query = f"""
        [out:json];
        area["ISO3166-1"="CH"][admin_level=2];
        node ["shop"="supermarket"](area);
        out;"""

# Web API request
r = requests.get(url, params={'data': query})
data = r.json()['elements']

# Save data to file
with open('supermarkets.json', 'w') as json_file:
    json.dump(data, json_file)

# Store data in data frame
df = json_normalize(data)

# Number of rows and columns
print(df.shape)

# First rows
df.head()
# Out:
# (3435, 265)
# tags.brand
# Coop                                     615
# Migros                                   536
# Denner                                   518
# Volg                                     292
# ALDI                                     118
# Lidl                                      88
# Spar                                      77
# Landi                                     68
# VOI Migros Partner                        30
# VOI                                       26
# Aldi                                      23
# Alnatura                                  21
# Outlet Migros                              7
# Migros-Outlet                              6
# Pam                                        5
# Crai                                       2
# 7-Eleven                                   1
# ZWIBOL                                     1
# avec                                       1
# Jumbo                                      1
# Rolog Krinner Cotub Titan Serac Molok      1
# Aldi Suisse                                1
# gazi                                       1
# Prima                                      1
# Eurospar                                   1
# coop                                       1
# Lidl Schweiz                               1
# Coop;wikidata=Q432564                      1
# Head, Fischer                              1
# Name: count, dtype: int64

# %%
# Overpass API URL
url = 'http://overpass-api.de/api/interpreter'

# Overpass turbo query
query = f"""
        [out:json];
        area["ISO3166-1"="CH"][admin_level=2];
        node ["shop"="supermarket"](area);
        out;"""

# Web API request
r = requests.get(url, params={'data': query})
data = r.json()['elements']

# Save data to file
with open('supermarkets.json', 'w') as json_file:
    json.dump(data, json_file)

# Store data in data frame
df = json_normalize(data)

# Number of rows and columns
print(df.shape)

# First rows
df.head()
# Out:
# (3436, 265)
#    type        id        lat       lon tags.brand tags.brand:wikidata  \
# 0  node  33126515  47.155616  9.037915       Spar             Q610492
# 1  node  36726161  47.226191  8.980329     Migros             Q680727
# 2  node  39768209  47.225154  8.969868       Coop             Q432564
# 3  node  39947904  47.376732  8.542161       Coop             Q432564
# 4  node  48932835  47.375020  8.522895     Migros             Q680727
#
#   tags.brand:wikipedia tags.name  \
# 0   en:SPAR (retailer)      Spar
# 1            de:Migros    Migros
# 2                  NaN      Coop
# 3    de:Coop (Schweiz)      Coop
# 4                  NaN    Migros
#
#                                   tags.opening_hours    tags.shop  ...  \
# 0  Mo-Th 08:00-19:00; Fr 08:00-20:00; Sa 08:00-17:00  supermarket  ...
# 1  Mo-Th 08:00-19:00, Fr 08:00-20:00, Sa 07:30-17...  supermarket  ...
# 2                                                NaN  supermarket  ...
# 3                                  Mo-Sa 06:00-22:00  supermarket  ...
# 4                          Mo-Sa 08:00-21:00; PH off  supermarket  ...
#
#   tags.diet:organic tags.diet:seafood tags.brand:website  \
# 0               NaN               NaN                NaN
# 1               NaN               NaN                NaN
# 2               NaN               NaN                NaN
# 3               NaN               NaN                NaN
# 4               NaN               NaN                NaN
#
#   tags.recycling:low_energy_bulbs tags.image tags.opening_hours:cafe  \
# 0                             NaN        NaN                     NaN
# 1                             NaN        NaN                     NaN
# 2                             NaN        NaN                     NaN
# 3                             NaN        NaN                     NaN
# 4                             NaN        NaN                     NaN
#
#   tags.currency:XBT tags.payment:lightning tags.payment:lightning_contactless  \
# 0               NaN                    NaN                                NaN
# 1               NaN                    NaN                                NaN
# 2               NaN                    NaN                                NaN
# 3               NaN                    NaN                                NaN
# 4               NaN                    NaN                                NaN
#
#   tags.payment:onchain
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#
# [5 rows x 265 columns]

# %% [markdown]
# ## Plot supermarkets on map

# %%
# Subset of supermarkets by brand
locations = df[["lat", "lon", "tags.brand", "tags.shop"]].loc[df["tags.brand"].isin(['Aldi'])]
print(locations.head(5))

# Create map
map = folium.Map(location=[locations.lat.mean(), 
                           locations.lon.mean()], 
                 zoom_start=8, 
                 control_scale=True)

# Add maker symbols
for index, location_info in locations.iterrows():
    folium.Marker([location_info["lat"], 
                   location_info["lon"]], 
                  popup=location_info["tags.brand"]).add_to(map)

# Plot map
map
# Out:
#            lat       lon tags.brand    tags.shop
# 18   47.241495  8.718371       Aldi  supermarket
# 25   47.501665  8.032409       Aldi  supermarket
# 386  46.963494  7.481840       Aldi  supermarket
# 511  46.990535  6.930410       Aldi  supermarket
# 618  46.187181  6.111268       Aldi  supermarket
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_185b2e150e7990c787fd1fa02755d5df {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_185b2e150e7990c787fd1fa02755d5df&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_185b2e150e7990c787fd1fa02755d5df = L.map(
#                 &quot;map_185b2e150e7990c787fd1fa02755d5df&quot;,
#                 {
#                     center: [46.974263430434775, 8.063082708695651],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_185b2e150e7990c787fd1fa02755d5df);
#
#
#
#
#
#             var tile_layer_71fe5677b09578aa5b8c105ebbbce2ef = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_71fe5677b09578aa5b8c105ebbbce2ef.addTo(map_185b2e150e7990c787fd1fa02755d5df);
#
#
#             var marker_b2b6bb53189cb33116acea5fc81ec507 = L.marker(
#                 [47.2414948, 8.7183709],
#                 {}
#             ).addTo(map_185b2e150e7990c787fd1fa02755d5df);
#
#
#         var popup_4e9d7845579c6891cf4d03b8e9457984 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_13166a6d5c87f564e7e010a7f783e13c = $(`&lt;div id=&quot;html_13166a6d5c87f564e7e010a7f783e13c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Aldi&lt;/div&gt;`)[0];
#                 popup_4e9d7845579c6891cf4d03b8e9457984.setContent(html_13166a6d5c87f564e7e010a7f783e13c);
#
#
#
#         marker_b2b6bb53189cb33116acea5fc81ec507.bindPopup(popup_4e9d7845579c6891cf4d03b8e9457984)
#         ;
#
#
#
#
#             var marker_1c8b50aff2c6b3d850abf01a652ab0a6 = L.marker(
#                 [47.501665, 8.0324095],
#                 {}
#             ).addTo(map_185b2e150e7990c787fd1fa02755d5df);
#
#
#         var popup_c9efedc018c5c674c857f087ff4f3675 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_db76497a9c077cae11e2e047c04368d9 = $(`&lt;div id=&quot;html_db76497a9c077cae11e2e047c04368d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Aldi&lt;/div&gt;`)[0];
#                 popup_c9efedc018c5c674c857f087ff4f3675.setContent(html_db76497a9c077cae11e2e047c04368d9);
#
#
#
#         marker_1c8b50aff2c6b3d850abf01a652ab0a6.bindPopup(popup_c9efedc018c5c674c857f087ff4f3675)
#         ;
#
#
#
#
#             var marker_5bc7a09040c871207defc3b904896336 = L.marker(
#                 [46.9634938, 7.4818402],
#                 {}
#             ).addTo(map_185b2e150e7990c787fd1fa02755d5df);
#
#
#         var popup_d70d4a3aa262d675e4bc0b3c1b2b0b6b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8a012521c659b7d510586830321aa03f = $(`&lt;div id=&quot;html_8a012521c659b7d510586830321aa03f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Aldi&lt;/div&gt;`)[0];
#                 popup_d70d4a3aa262d675e4bc0b3c1b2b0b6b.setContent(html_8a012521c659b7d510586830321aa03f);
#
#
#
#         marker_5bc7a09040c871207defc3b904896336.bindPopup(popup_d70d4a3aa262d675e4bc0b3c1b2b0b6b)
#         ;
#
#
#
#
#             var marker_b2ff44a7f4d2eaa5698381ff1c56059c = L.marker(
#                 [46.9905345, 6.9304104],
#                 {}
#             ).addTo(map_185b2e150e7990c787fd1fa02755d5df);
#
#
#         var popup_a42d2ea3384cf705899985a92ff07e94 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1fa9d8c77b75667b13722710470eb644 = $(`&lt;div id=&quot;html_1fa9d8c77b75667b13722710470eb644&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Aldi&lt;/div&gt;`)[0];
#                 popup_a42d2ea3384cf705899985a92ff07e94.setContent(html_1fa9d8c77b75667b13722710470eb644);
#
#
#
#         marker_b2ff44a7f4d2eaa5698381ff1c56059c.bindPopup(popup_a42d2ea3384cf705899985a92ff07e94)
#         ;
#
#
#
#
#             var marker_6da8d9f83370d8cfe90085e45e457679 = L.marker(
#                 [46.187181, 6.1112678],
#                 {}
#             ).addTo(map_185b2e150e7990c787fd1fa02755d5df);
#
#
#         var popup_ea484922fe3ea134e8ecd09a637034c2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8b4a4503b18dcbfc46eb755fe2e3cf8b = $(`&lt;div id=&quot;html_8b4a4503b18dcbfc46eb755fe2e3cf8b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Aldi&lt;/div&gt;`)[0];
#                 popup_ea484922fe3ea134e8ecd09a637034c2.setContent(html_8b4a4503b18dcbfc46eb755fe2e3cf8b);
#
#
#
#         marker_6da8d9f83370d8cfe90085e45e457679.bindPopup(popup_ea484922fe3ea134e8ecd09a637034c2)
#         ;
#
#
#
#
#             var marker_9a88d510acb6364d366b42962444a6ca = L.marker(
#                 [47.0420298, 9.4335724],
#                 {}

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each submitted notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# POSIX
# Linux | 6.5.0-1025-azure
# Datetime: 2024-09-20 13:27:30
# Python Version: 3.11.10
# -----------------------------------
